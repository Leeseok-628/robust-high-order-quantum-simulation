# %% [markdown]
# # Fig. 3: Naive implementation \& 1st- and 2nd-order DCGs

# %%
from construction1_ising import *

J12, J13, J23 = -0.547, 0.925, -0.747 #choose randomly
taus = construction1_nonzero_delays(J12, J13, J23, T=1.0)

data = benchmark_full_ising(
    J12=J12,
    J13=J13,
    J23=J23,
    tp_list=np.logspace(-4, -1, 20),
    T=1.0,
    taus=taus,
)

#print(data["slope_naive"], data["slope_q1"], data["slope_q2"])
plot_ising_benchmark(data)
