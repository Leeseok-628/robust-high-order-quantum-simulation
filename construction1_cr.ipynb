# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Fig. 4: Trotter-based pulse sequences

# %%
from construction1_cr import benchmark_construction1_cr, plot_cr_benchmark

# ------------------------------------------------
# benchmark
# ------------------------------------------------
Tlist = np.logspace(-2, 0, 20)
tp_list = np.array([1e-5, 1e-4])

bench = benchmark_construction1_cr(
    Tlist=Tlist,
    tp_list=tp_list,
)

results = bench["results"]

plot_cr_benchmark(
        bench,
        tp_target=1e-4,
        ylabel=r"$1-F$",
    )

# %% [markdown]
# # Fig. 9: Multi-product formulas-based pulse sequences

# %%
from construction1_cr_mpf import benchmark_cr_mpf_observable, plot_cr_mpf_observable

bench = benchmark_cr_mpf_observable(
    tp=1e-5,
    observable="XXII",
    initial_state="0101",
)

plot_cr_mpf_observable(
    bench,
    ylabel=r"$\varepsilon_{\mathrm{MPF}}(X_1X_2,T)$",
)
