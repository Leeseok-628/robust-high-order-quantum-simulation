# %%
import numpy as np

# %% [markdown]
# # Fig. 5: Trotter-based pulse sequences

# %%
from construction2_hb import run_algorithm2_demo

run_algorithm2_demo(
    Jx=0.20,
    Jy=0.15,
    Jz=0.35,
    tp_target=1e-4,
    Tlist=np.logspace(-1.2, 0, 20),
)

# %% [markdown]
# # Fig. 10: Multi-product formulas-based pulse sequences

# %%
from construction2_hb_mpf import (
    benchmark_algorithm2_mpf_observable,
    plot_algorithm2_mpf_observable,
)

bench = benchmark_algorithm2_mpf_observable(
    tp=1e-5,
    observable="XXII",
    initial_state="0101",
)

plot_algorithm2_mpf_observable(
    bench,
    ylabel=r"$\varepsilon_{\mathrm{MPF}}(X_1X_2,T)$",
)
